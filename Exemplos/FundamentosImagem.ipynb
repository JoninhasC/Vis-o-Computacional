# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Exemplo Prático: Abrindo e Exibindo uma Imagem

# %%
# Carregar a imagem
imagem = cv2.imread("gato.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter de BGR para RGB (para exibição correta no matplotlib)
    imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

    # Exibir a imagem no Jupyter Notebook
    plt.imshow(imagem_rgb)
    plt.axis('off')  # Remove os eixos para uma exibição mais limpa
    plt.show()

# %%
# Carregar a imagem
imagem = cv2.imread("televisao.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter de BGR para RGB (para exibição correta no matplotlib)
    imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

    # Exibir a imagem no Jupyter Notebook
    plt.imshow(imagem_rgb)
    plt.axis('off')  # Remove os eixos para uma exibição mais limpa
    plt.show()

# %%
# Carregar a imagem
imagem = cv2.imread("vermelho.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter de BGR para RGB (para exibição correta no matplotlib)
    imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

    # Exibir a imagem no Jupyter Notebook
    plt.imshow(imagem_rgb)
    plt.axis('off')  # Remove os eixos para uma exibição mais limpa
    plt.show()

# %% [markdown]
# Exemplo Prático:Obtendo Informações da Imagem

# %%
# Carregar a imagem
imagem = cv2.imread("gato.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Obter altura, largura e canais
    altura, largura, canais = imagem.shape

    # Obter a profundidade de cor
    profundidade_cor = imagem.dtype

    # Exibir informações
    print(f"Dimensão: {largura * altura} pixels")
    print(f"Resolução: {largura}x{altura}")
    print(f"Número de canais: {canais}")
    print(f"Profundidade de cor: {profundidade_cor}")
# Out:
# Dimensão: 251520 pixels
# Resolução: 640x393
# Número de canais: 3
# Profundidade de cor: uint8

# %%
# Carregar a imagem
imagem = cv2.imread("televisao.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Obter altura, largura e canais
    altura, largura, canais = imagem.shape

    # Obter a profundidade de cor
    profundidade_cor = imagem.dtype

    # Exibir informações
    print(f"Dimensão: {largura * altura} pixels")
    print(f"Resolução: {largura}x{altura}")
    print(f"Número de canais: {canais}")
    print(f"Profundidade de cor: {profundidade_cor}")
# Out:
# Dimensão: 273280 pixels
# Resolução: 640x427
# Número de canais: 3
# Profundidade de cor: uint8

# %%
# Carregar a imagem
imagem = cv2.imread("vermelho.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Obter altura, largura e canais
    altura, largura, canais = imagem.shape

    # Obter a profundidade de cor
    profundidade_cor = imagem.dtype

    # Exibir informações
    print(f"Dimensão: {largura * altura} pixels")
    print(f"Resolução: {largura}x{altura}")
    print(f"Número de canais: {canais}")
    print(f"Profundidade de cor: {profundidade_cor}")
# Out:
# Dimensão: 67500 pixels
# Resolução: 300x225
# Número de canais: 3
# Profundidade de cor: uint8

# %% [markdown]
# Exemplo Prático:Convertendo para Tons de Cinza

# %%
# Carregar a imagem
imagem = cv2.imread("gato.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

    # Obter a profundidade de cor
    profundidade_cor = imagem_cinza.dtype
    print("Profundidade de cor:", profundidade_cor)

    # Exibir imagem dentro do Jupyter
    plt.imshow(imagem_cinza, cmap='gray')
    plt.axis('off')  # Remove os eixos para visualização mais limpa
    plt.show()
# Out:
# Profundidade de cor: uint8

# %%
# Carregar a imagem
imagem = cv2.imread("televisao.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

    # Obter a profundidade de cor
    profundidade_cor = imagem_cinza.dtype
    print("Profundidade de cor:", profundidade_cor)

    # Exibir imagem dentro do Jupyter
    plt.imshow(imagem_cinza, cmap='gray')
    plt.axis('off')  # Remove os eixos para visualização mais limpa
    plt.show()
# Out:
# Profundidade de cor: uint8

# %%
# Carregar a imagem
imagem = cv2.imread("vermelho.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

    # Obter a profundidade de cor
    profundidade_cor = imagem_cinza.dtype
    print("Profundidade de cor:", profundidade_cor)

    # Exibir imagem dentro do Jupyter
    plt.imshow(imagem_cinza, cmap='gray')
    plt.axis('off')  # Remove os eixos para visualização mais limpa
    plt.show()
# Out:
# Profundidade de cor: uint8

# %% [markdown]
# Exemplo Prático: Acessando um Pixel Específico

# %%
# Carregar a imagem
imagem = cv2.imread("gato.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

    # Definir coordenadas do recorte (y1:y2, x1:x2)
    x1, y1 = 50, 50   # Canto superior esquerdo
    x2, y2 = 200, 200  # Canto inferior direito

    # Verificar se as coordenadas estão dentro da imagem
    altura, largura = imagem_cinza.shape
    if 0 <= x1 < largura and 0 <= x2 <= largura and 0 <= y1 < altura and 0 <= y2 <= altura:
        # Recortar a imagem
        imagem_recortada = imagem_cinza[y1:y2, x1:x2]

        # Exibir a parte recortada
        plt.imshow(imagem_recortada, cmap='gray')
        plt.axis('off')  # Remove os eixos para uma visualização mais limpa
        plt.show()
    else:
        print("Erro: Coordenadas do recorte estão fora dos limites da imagem.")

# %%
# Carregar a imagem
imagem = cv2.imread("televisao.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

    # Definir coordenadas do recorte (y1:y2, x1:x2)
    x1, y1 = 50, 50   # Canto superior esquerdo
    x2, y2 = 200, 200  # Canto inferior direito

    # Verificar se as coordenadas estão dentro da imagem
    altura, largura = imagem_cinza.shape
    if 0 <= x1 < largura and 0 <= x2 <= largura and 0 <= y1 < altura and 0 <= y2 <= altura:
        # Recortar a imagem
        imagem_recortada = imagem_cinza[y1:y2, x1:x2]

        # Exibir a parte recortada
        plt.imshow(imagem_recortada, cmap='gray')
        plt.axis('off')  # Remove os eixos para uma visualização mais limpa
        plt.show()
    else:
        print("Erro: Coordenadas do recorte estão fora dos limites da imagem.")

# %%
# Carregar a imagem
imagem = cv2.imread("vermelho.jpg")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Erro: Não foi possível carregar a imagem.")
else:
    # Converter para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

    # Definir coordenadas do recorte (y1:y2, x1:x2)
    x1, y1 = 50, 50   # Canto superior esquerdo
    x2, y2 = 200, 200  # Canto inferior direito

    # Verificar se as coordenadas estão dentro da imagem
    altura, largura = imagem_cinza.shape
    if 0 <= x1 < largura and 0 <= x2 <= largura and 0 <= y1 < altura and 0 <= y2 <= altura:
        # Recortar a imagem
        imagem_recortada = imagem_cinza[y1:y2, x1:x2]

        # Exibir a parte recortada
        plt.imshow(imagem_recortada, cmap='gray')
        plt.axis('off')  # Remove os eixos para uma visualização mais limpa
        plt.show()
    else:
        print("Erro: Coordenadas do recorte estão fora dos limites da imagem.")
